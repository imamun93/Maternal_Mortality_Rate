# %%
import pandas as pd

# %%
df = pd.read_csv('popmean.csv')
df.iloc[:, 2:]
# Out:
#                  Country Name Country Code 2015 [YR2015]
# 0                    Zimbabwe          ZWE      15777451
# 1                      Zambia          ZMB      16100587
# 2                 Yemen, Rep.          YEM      26916207
# 3                     Vietnam          VNM      93571567
# 4               Venezuela, RB          VEN      31155134
# 5                     Vanuatu          VUT        264603
# 6                  Uzbekistan          UZB      31298900
# 7                     Uruguay          URY       3431552
# 8               United States          USA     321039839
# 9              United Kingdom          GBR      65128861
# 10       United Arab Emirates          ARE       9154302
# 11                    Ukraine          UKR      45154029
# 12                     Uganda          UGA      40144870
# 13                     Tuvalu          TUV         11001
# 14   Turks and Caicos Islands          TCA         34339
# ...

# %%
# df[['Country Name','2015 [YR2015]']]

df = df.rename(columns={'Country Name': 'Country', '2015 [YR2015]': 'Population'})

# %%
pop = df[['Country', 'Population']]

# %%
fr_df = pd.read_csv('fertility_rate.csv')
fr_df = fr_df.rename(columns = {'2015 [YR2015]': 'Fertility Rate'})

fr = fr_df[['Country Name', 'Fertility Rate']]

pop
# Out:
#                       Country Population
# 0                    Zimbabwe   15777451
# 1                      Zambia   16100587
# 2                 Yemen, Rep.   26916207
# 3                     Vietnam   93571567
# 4               Venezuela, RB   31155134
# 5                     Vanuatu     264603
# 6                  Uzbekistan   31298900
# 7                     Uruguay    3431552
# 8               United States  321039839
# 9              United Kingdom   65128861
# 10       United Arab Emirates    9154302
# 11                    Ukraine   45154029
# 12                     Uganda   40144870
# 13                     Tuvalu      11001
# 14   Turks and Caicos Islands      34339
# 15               Turkmenistan    5565284
# 16                     Turkey   78271472
# 17                    Tunisia   11273661
# 18        Trinidad and Tobago    1360092
# 19                      Tonga     106364
# 20                       Togo    7416802
# 21                Timor-Leste    1240977
# ...

# %%
fr
# Out:
#                  Country Name  Fertility Rate
# 0                 Afghanistan             4.8
# 1                     Albania             1.7
# 2                     Algeria             2.8
# 3              American Samoa             NaN
# 4                     Andorra             NaN
# 5                      Angola             5.8
# 6         Antigua and Barbuda             2.1
# 7                  Arab World             3.4
# 8                   Argentina             2.3
# 9                     Armenia             1.6
# 10                      Aruba             1.8
# 11                  Australia             1.8
# 12                    Austria             1.5
# 13                 Azerbaijan             1.9
# 14               Bahamas, The             1.8
# 15                    Bahrain             2.1
# 16                 Bangladesh             2.1
# 17                   Barbados             1.8
# 18                    Belarus             1.7
# ...

# %%
pop = pd.read_csv('popmean.csv')

# %%
pop=pop.iloc[:, 2:]

# %%
pop= pop.drop(columns= 'Country Code')

# %%
pop
# Out:
#                  Country Name 2015 [YR2015]
# 0                    Zimbabwe      15777451
# 1                      Zambia      16100587
# 2                 Yemen, Rep.      26916207
# 3                     Vietnam      93571567
# 4               Venezuela, RB      31155134
# 5                     Vanuatu        264603
# 6                  Uzbekistan      31298900
# 7                     Uruguay       3431552
# 8               United States     321039839
# 9              United Kingdom      65128861
# 10       United Arab Emirates       9154302
# 11                    Ukraine      45154029
# 12                     Uganda      40144870
# 13                     Tuvalu         11001
# 14   Turks and Caicos Islands         34339
# 15               Turkmenistan       5565284
# 16                     Turkey      78271472
# 17                    Tunisia      11273661
# 18        Trinidad and Tobago       1360092
# 19                      Tonga        106364
# ...

# %%
pop= pop.sort_values(['Country Name'], axis=0, ascending=True)

# %%
gdp= pd.read_csv('countrygdp.csv')
gdp
# Out:
#                                           Series Name     Series Code  \
# 0                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 5                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 6                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 7                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 8                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 9                        GDP per capita (current US$)  NY.GDP.PCAP.CD
# 10                       GDP per capita (current US$)  NY.GDP.PCAP.CD
# 11                       GDP per capita (current US$)  NY.GDP.PCAP.CD
# ...

# %%
gdp= gdp.iloc[:, 2:]

# %%
gdp= gdp.drop(columns= 'Country Code')

# %%
gdp
# Out:
#                                           Country Name     2015 [YR2015]
# 0                                          Afghanistan    569.5779229167
# 1                                              Albania  3952.83078116586
# 2                                              Algeria  4160.22006671831
# 3                                       American Samoa  11865.9632317194
# 4                                              Andorra  36038.2676044596
# 5                                               Angola   3683.5526074127
# 6                                  Antigua and Barbuda  13659.1479142644
# 7                                            Argentina  13698.2934384857
# 8                                              Armenia  3617.93574555176
# 9                                                Aruba                ..
# 10                                           Australia  56561.4123818054
# 11                                             Austria  44206.7842820834
# ...

# %%
pop = pop.set_index('Country Name')
pop = pop.drop("Korea, Dem. People's Rep.", axis=0)

# %%
pop = pop.drop("East Asia & Pacific (IDA & IBRD)", axis=0)

# %%
pop= pop.reset_index()

# %%
countries_pop = pop['Country Name'].tolist()

# %%
all_gdp_countries = gdp['Country Name'].tolist()
filtered_gdp = []

all_gdp_countries
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'El Salvador',
# ...

# %%
# gdp_indexes = []
# for country in countries_pop:
#     try:
#         index = all_gdp_countries.index(country)
#         gdp_indexes.append(index)
#     except:
#         print(country)
# #         print(gdp['Country Name'])

# len(pop)

# %%
# pop = pop.set_index('Country Name')
# pop = pop.drop("Korea, Dem. People's Rep.", axis=0)

# %%
# pop = pop.set_index('Country Name')
# pop = pop.drop("East Asia & Pacific (IDA & IBRD)", axis=0)

# %%
len(pop)
# Out:
# 205

# %%
pop= pop.reset_index()

# %%
pop
# Out:
#      index              Country Name 2015 [YR2015]
# 0        0               Afghanistan      33736494
# 1        1                   Albania       2880703
# 2        2                   Algeria      39871528
# 3        3                    Angola      27859305
# 4        4                 Argentina      43417765
# 5        5                   Armenia       2916950
# 6        6                     Aruba        104341
# 7        7                 Australia      23850784
# 8        8                   Austria       8642699
# 9        9                Azerbaijan       9649341
# 10      10                   Bahrain       1371855
# 11      11                Bangladesh     161200886
# 12      12                  Barbados        284217
# 13      13                   Belarus       9489616
# 14      14                   Belgium      11274196
# 15      15                    Belize        359288
# 16      16                     Benin      10575952
# ...

# %%
gdp_vals = []
for country in countries_pop:
    try:
        index = all_gdp_countries.index(country)
        gdp_vals.append(gdp.loc[index, '2015 [YR2015]'])
        
    except:
        print(country)
#         print(gdp['Country Name'])

gdp_vals
# Out:
# ['569.5779229167',
#  '3952.83078116586',
#  '4160.22006671831',
#  '3683.5526074127',
#  '13698.2934384857',
#  '3617.93574555176',
#  '..',
#  '56561.4123818054',
#  '44206.7842820834',
#  '5500.31038244408',
#  '22688.8782442968',
#  '1210.15876939761',
#  '16129.0492827663',
#  '5949.10630699748',
#  '40361.1541907535',
#  '4950.25606198927',
#  '783.963077800944',
#  '..',
#  '2615.31022007844',
#  '3077.02619917158',
#  '4584.24254781755',
#  '6527.50816086673',
#  '8750.22299607324',
#  '30967.890506377',
#  '6993.47554370696',
#  '575.314454176312',
#  '300.676556925263',
#  '2995.15055267969',
#  '1163.18977018231',
#  '1353.92448961447',
#  '43525.3701865304',
#  '..',
#  '348.381427149795',
#  '12456.4265235151',
#  '784.172307238762',
#  '..',
#  '13736.6356879313',
#  '8069.21302389511',
#  '6044.52555566556',
#  '727.646386827046',
#  '1712.12114632566',
#  '11393.0239509727',
#  '1434.32661467505',
#  '11757.8900417938',
#  '7602.26121831897',
#  '..',
# ...

# %%
pop['gdp'] = gdp_vals

# %%
pop
# Out:
#      index              Country Name 2015 [YR2015]               gdp
# 0        0               Afghanistan      33736494    569.5779229167
# 1        1                   Albania       2880703  3952.83078116586
# 2        2                   Algeria      39871528  4160.22006671831
# 3        3                    Angola      27859305   3683.5526074127
# 4        4                 Argentina      43417765  13698.2934384857
# 5        5                   Armenia       2916950  3617.93574555176
# 6        6                     Aruba        104341                ..
# 7        7                 Australia      23850784  56561.4123818054
# 8        8                   Austria       8642699  44206.7842820834
# 9        9                Azerbaijan       9649341  5500.31038244408
# 10      10                   Bahrain       1371855  22688.8782442968
# 11      11                Bangladesh     161200886  1210.15876939761
# 12      12                  Barbados        284217  16129.0492827663
# ...

# %%
mat_leave= pd.read_csv('matleave2.csv')
mat_leave
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
maternity= mat_leave[['Country Name', '2015']]
maternity
# Out:
#                                           Country Name  2015
# 0                                                Aruba   NaN
# 1                                          Afghanistan   1.0
# 2                                               Angola   1.0
# 3                                              Albania   1.0
# 4                                              Andorra   NaN
# 5                                           Arab World   NaN
# 6                                 United Arab Emirates   1.0
# 7                                            Argentina   1.0
# 8                                              Armenia   1.0
# 9                                       American Samoa   NaN
# 10                                 Antigua and Barbuda   1.0
# 11                                           Australia   0.0
# 12                                             Austria   1.0
# 13                                          Azerbaijan   1.0
# ...

# %%
all_maternity_countries = maternity['Country Name'].tolist()
maternity_vals = []
for country in countries_pop:
    try:
        index = all_maternity_countries.index(country)
        maternity_vals.append(maternity.loc[index, '2015'])
        
    except:
        print(country)
#         print(gdp['Country Name'])

len(maternity_vals)
# Out:
# nan
# nan
# nan
# nan
# nan
# 200

# %%
nan= [0, 0, 0, 0, 0]
mat_le = maternity_vals + nan
mat_le= list(mat_le)

# %%
len(mat_le)
# Out:
# 205

# %%
pop['maternity_leaves']= mat_le

# %%
pop
# Out:
#      index              Country Name 2015 [YR2015]               gdp  \
# 0        0               Afghanistan      33736494    569.5779229167
# 1        1                   Albania       2880703  3952.83078116586
# 2        2                   Algeria      39871528  4160.22006671831
# 3        3                    Angola      27859305   3683.5526074127
# 4        4                 Argentina      43417765  13698.2934384857
# 5        5                   Armenia       2916950  3617.93574555176
# 6        6                     Aruba        104341                ..
# 7        7                 Australia      23850784  56561.4123818054
# 8        8                   Austria       8642699  44206.7842820834
# 9        9                Azerbaijan       9649341  5500.31038244408
# 10      10                   Bahrain       1371855  22688.8782442968
# 11      11                Bangladesh     161200886  1210.15876939761
# 12      12                  Barbados        284217  16129.0492827663
# ...

# %%
fertiliy= pd.read_csv('fertility_rate.csv')
fertiliy
# Out:
#                                   Series Name     Series Code  \
# 0    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 1    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 2    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 3    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 4    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 5    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 6    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 7    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 8    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 9    Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 10   Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 11   Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 12   Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# 13   Fertility rate, total (births per woman)  SP.DYN.TFRT.IN
# ...

# %%
fertiliy= fertiliy.iloc[:, 2:]
fertiliy
# Out:
#                  Country Name Country Code Scale (Precision)  2015 [YR2015]
# 0                 Afghanistan          AFG        Unit (0.0)            4.8
# 1                     Albania          ALB        Unit (0.0)            1.7
# 2                     Algeria          DZA        Unit (0.0)            2.8
# 3              American Samoa          ASM        Unit (0.0)            NaN
# 4                     Andorra          AND        Unit (0.0)            NaN
# 5                      Angola          AGO        Unit (0.0)            5.8
# 6         Antigua and Barbuda          ATG        Unit (0.0)            2.1
# 7                  Arab World          ARB        Unit (0.0)            3.4
# 8                   Argentina          ARG        Unit (0.0)            2.3
# 9                     Armenia          ARM        Unit (0.0)            1.6
# 10                      Aruba          ABW        Unit (0.0)            1.8
# ...

# %%
fertiliy= fertiliy.drop(columns= ['Country Code', 'Scale (Precision)'])
fertiliy
# Out:
#                  Country Name  2015 [YR2015]
# 0                 Afghanistan            4.8
# 1                     Albania            1.7
# 2                     Algeria            2.8
# 3              American Samoa            NaN
# 4                     Andorra            NaN
# 5                      Angola            5.8
# 6         Antigua and Barbuda            2.1
# 7                  Arab World            3.4
# 8                   Argentina            2.3
# 9                     Armenia            1.6
# 10                      Aruba            1.8
# 11                  Australia            1.8
# 12                    Austria            1.5
# 13                 Azerbaijan            1.9
# 14               Bahamas, The            1.8
# 15                    Bahrain            2.1
# 16                 Bangladesh            2.1
# 17                   Barbados            1.8
# 18                    Belarus            1.7
# 19                    Belgium            1.7
# ...

# %%
fertility= fertiliy

# %%
all_fertility_countries = fertility['Country Name'].tolist()
fertility_vals = []
for country in countries_pop:
    try:
        index = all_fertility_countries.index(country)
        fertility_vals.append(fertility.loc[index, '2015 [YR2015]'])
        
    except:
        print(country)
#         print(gdp['Country Name'])

fertility_vals
# Out:
# [4.8,
#  1.7,
#  2.8,
#  5.8,
#  2.3,
#  1.6,
#  1.8,
#  1.8,
#  1.5,
#  1.9,
#  2.1,
#  2.1,
#  1.8,
#  1.7,
#  1.7,
#  2.5,
#  5.0,
#  1.6,
#  2.1,
#  2.9,
#  1.3,
#  2.8,
#  1.7,
#  1.9,
#  1.5,
#  5.4,
#  5.8,
#  2.4,
#  2.6,
#  4.8,
#  1.6,
#  nan,
#  4.9,
#  1.5,
#  6.1,
#  1.5,
#  1.8,
#  1.6,
#  1.9,
#  4.4,
#  4.7,
#  1.8,
#  5.0,
#  1.4,
#  1.7,
#  1.9,
#  1.4,
#  1.6,
#  1.7,
#  2.9,
#  nan,
#  2.5,
#  2.5,
#  2.1,
#  4.2,
#  1.6,
#  3.1,
#  4.3,
#  1.6,
#  2.4,
#  2.5,
#  1.7,
#  2.0,
#  2.0,
#  3.9,
#  5.5,
#  2.0,
#  1.5,
#  4.0,
#  nan,
#  1.3,
#  2.0,
#  2.1,
#  2.4,
#  3.0,
#  4.9,
#  4.7,
#  2.5,
#  3.0,
#  2.5,
#  1.2,
#  1.5,
#  1.8,
#  2.4,
#  2.4,
#  1.7,
#  4.4,
#  1.9,
#  nan,
#  3.1,
#  1.4,
#  2.0,
#  1.5,
#  3.4,
#  2.7,
#  3.9,
#  3.7,
#  1.2,
#  2.1,
#  2.0,
#  3.2,
#  1.7,
#  3.1,
#  4.7,
#  2.3,
#  1.4,
#  1.7,
#  1.5,
#  4.2,
#  4.6,
#  2.1,
#  2.1,
#  6.1,
#  1.5,
#  4.7,
#  1.4,
#  2.2,
#  1.2,
#  nan,
#  2.8,
#  1.7,
#  2.5,
#  5.3,
#  2.2,
#  3.5,
# ...

# %%
len(fertility_vals)
# Out:
# 205

# %%
# def check():
# #     foo = ['True' for country in fertility['Country Name'].tolist() if country == "Korea, Dem. People's Rep."]
# #     return foo
#     if "Korea, Dem. People's Rep." in fertility['Country Name'].tolist():
#         return 'True'

# check()

# %%
pop['fertility_rate']= fertility_vals

# %%
pop
# Out:
#      index              Country Name 2015 [YR2015]               gdp  \
# 0        0               Afghanistan      33736494    569.5779229167
# 1        1                   Albania       2880703  3952.83078116586
# 2        2                   Algeria      39871528  4160.22006671831
# 3        3                    Angola      27859305   3683.5526074127
# 4        4                 Argentina      43417765  13698.2934384857
# 5        5                   Armenia       2916950  3617.93574555176
# 6        6                     Aruba        104341                ..
# 7        7                 Australia      23850784  56561.4123818054
# 8        8                   Austria       8642699  44206.7842820834
# 9        9                Azerbaijan       9649341  5500.31038244408
# 10      10                   Bahrain       1371855  22688.8782442968
# 11      11                Bangladesh     161200886  1210.15876939761
# 12      12                  Barbados        284217  16129.0492827663
# ...

# %%
mortality= pd.read_csv('mortality2.csv')
mortality
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
mort = mortality[['Country Name', '2015']]
mort
# Out:
#                                           Country Name   2015
# 0                                                Aruba    NaN
# 1                                          Afghanistan  396.0
# 2                                               Angola  477.0
# 3                                              Albania   29.0
# 4                                              Andorra    NaN
# 5                                           Arab World  156.0
# 6                                 United Arab Emirates    6.0
# 7                                            Argentina   52.0
# 8                                              Armenia   25.0
# 9                                       American Samoa    NaN
# 10                                 Antigua and Barbuda    NaN
# 11                                           Australia    6.0
# 12                                             Austria    4.0
# 13                                          Azerbaijan   25.0
# ...

# %%
all_mortality_countries = mort['Country Name'].tolist()
mortality_values = []
for country in countries_pop:
    try:
        index = all_mortality_countries.index(country)
        mortality_values.append(mort.loc[index, '2015'])
        
    except:
        print(country)
#         print(gdp['Country Name'])

len(mortality_values)
# Out:
# nan
# nan
# nan
# nan
# nan
# 200

# %%
nan= ['Null', 'Null', 'Null', 'Null', 'Null']
mortality = mortality_values + nan
mortality= list(mortality)
len(mortality)
# Out:
# 205

# %%
pop['Mortality Rate']= mortality

# %%
pop.drop(columns='index')
# Out:
#                  Country Name 2015 [YR2015]               gdp  \
# 0                 Afghanistan      33736494    569.5779229167
# 1                     Albania       2880703  3952.83078116586
# 2                     Algeria      39871528  4160.22006671831
# 3                      Angola      27859305   3683.5526074127
# 4                   Argentina      43417765  13698.2934384857
# 5                     Armenia       2916950  3617.93574555176
# 6                       Aruba        104341                ..
# 7                   Australia      23850784  56561.4123818054
# 8                     Austria       8642699  44206.7842820834
# 9                  Azerbaijan       9649341  5500.31038244408
# 10                    Bahrain       1371855  22688.8782442968
# 11                 Bangladesh     161200886  1210.15876939761
# 12                   Barbados        284217  16129.0492827663
# 13                    Belarus       9489616  5949.10630699748
# ...

# %%
healthcare_countries = ['Norway', 'New Zealand', 'Japan', 'Germany', 'Belgium', 'United Kingdom', 'Kuwait', 'Sweden', 'Bahrain', 'Brunei', 'Canada', 'Netherlands', 'Austria', 'United Arab Emirates', 'Finland', 'Slovenia', 'Denmark', 'Luxembourg', 'France', 'Australia', 'Ireland', 'Italy', 'Portugal', 'Cyprus', 'Greece', 'Spain', 'South Korea', 'Iceland', 'Hong Kong', 'Singapore', 'Switzerland', 'Israel']

# %%
countries_test1 = countries_pop.copy()
for country in countries_pop:
    if country in healthcare_countries:
        countries_test1[countries_pop.index(country)] = 1
    else:
        countries_test1[countries_pop.index(country)] = 0
        
#iterating through all countries we are looking at. if the country is in the list of countries with healthcare, make its value 1. otherwise, make its value 0.

# %%
pop['healthcare'] = countries_test1

# %%
pop
# Out:
#      index              Country Name 2015 [YR2015]               gdp  \
# 0        0               Afghanistan      33736494    569.5779229167
# 1        1                   Albania       2880703  3952.83078116586
# 2        2                   Algeria      39871528  4160.22006671831
# 3        3                    Angola      27859305   3683.5526074127
# 4        4                 Argentina      43417765  13698.2934384857
# 5        5                   Armenia       2916950  3617.93574555176
# 6        6                     Aruba        104341                ..
# 7        7                 Australia      23850784  56561.4123818054
# 8        8                   Austria       8642699  44206.7842820834
# 9        9                Azerbaijan       9649341  5500.31038244408
# 10      10                   Bahrain       1371855  22688.8782442968
# 11      11                Bangladesh     161200886  1210.15876939761
# 12      12                  Barbados        284217  16129.0492827663
# ...

# %%
pop= pop.replace(to_replace= '..', value= 'NaN')
pop
# Out:
#      index              Country Name 2015 [YR2015]               gdp  \
# 0        0               Afghanistan      33736494    569.5779229167
# 1        1                   Albania       2880703  3952.83078116586
# 2        2                   Algeria      39871528  4160.22006671831
# 3        3                    Angola      27859305   3683.5526074127
# 4        4                 Argentina      43417765  13698.2934384857
# 5        5                   Armenia       2916950  3617.93574555176
# 6        6                     Aruba        104341               NaN
# 7        7                 Australia      23850784  56561.4123818054
# 8        8                   Austria       8642699  44206.7842820834
# 9        9                Azerbaijan       9649341  5500.31038244408
# 10      10                   Bahrain       1371855  22688.8782442968
# 11      11                Bangladesh     161200886  1210.15876939761
# 12      12                  Barbados        284217  16129.0492827663
# ...

# %%
pop= pop.drop(columns=['index'])
pop
# Out:
#                  Country Name 2015 [YR2015]               gdp  \
# 0                 Afghanistan      33736494    569.5779229167
# 1                     Albania       2880703  3952.83078116586
# 2                     Algeria      39871528  4160.22006671831
# 3                      Angola      27859305   3683.5526074127
# 4                   Argentina      43417765  13698.2934384857
# 5                     Armenia       2916950  3617.93574555176
# 6                       Aruba        104341               NaN
# 7                   Australia      23850784  56561.4123818054
# 8                     Austria       8642699  44206.7842820834
# 9                  Azerbaijan       9649341  5500.31038244408
# 10                    Bahrain       1371855  22688.8782442968
# 11                 Bangladesh     161200886  1210.15876939761
# 12                   Barbados        284217  16129.0492827663
# 13                    Belarus       9489616  5949.10630699748
# ...

# %%
#dropna()
pop.tail()
# Out:
#     Country Name 2015 [YR2015]  gdp  maternity_leaves  fertility_rate  \
# 200          NaN           NaN  NaN               0.0             NaN
# 201          NaN           NaN  NaN               0.0             NaN
# 202          NaN           NaN  NaN               0.0             NaN
# 203          NaN           NaN  NaN               0.0             NaN
# 204          NaN           NaN  NaN               0.0             NaN
#
#     Mortality Rate  healthcare
# 200           Null         0.0
# 201           Null         NaN
# 202           Null         NaN
# 203           Null         NaN
# 204           Null         NaN

# %%
pop= pop.replace(to_replace= 'Null', value= 'NaN')
pop
# Out:
#                  Country Name 2015 [YR2015]               gdp  \
# 0                 Afghanistan      33736494    569.5779229167
# 1                     Albania       2880703  3952.83078116586
# 2                     Algeria      39871528  4160.22006671831
# 3                      Angola      27859305   3683.5526074127
# 4                   Argentina      43417765  13698.2934384857
# 5                     Armenia       2916950  3617.93574555176
# 6                       Aruba        104341               NaN
# 7                   Australia      23850784  56561.4123818054
# 8                     Austria       8642699  44206.7842820834
# 9                  Azerbaijan       9649341  5500.31038244408
# 10                    Bahrain       1371855  22688.8782442968
# 11                 Bangladesh     161200886  1210.15876939761
# 12                   Barbados        284217  16129.0492827663
# 13                    Belarus       9489616  5949.10630699748
# ...

# %%
pop = pop[:200]  ##get rid of NaN countries

# %%
pop = pop.rename(columns={'Mortality Rate':'mortality_rate'})

# %%
pop = pop[pop.mortality_rate != 'None']

# %%
pop
# Out:
#                  Country Name 2015 [YR2015]               gdp  \
# 0                 Afghanistan      33736494    569.5779229167
# 1                     Albania       2880703  3952.83078116586
# 2                     Algeria      39871528  4160.22006671831
# 3                      Angola      27859305   3683.5526074127
# 4                   Argentina      43417765  13698.2934384857
# 5                     Armenia       2916950  3617.93574555176
# 6                       Aruba        104341               NaN
# 7                   Australia      23850784  56561.4123818054
# 8                     Austria       8642699  44206.7842820834
# 9                  Azerbaijan       9649341  5500.31038244408
# 10                    Bahrain       1371855  22688.8782442968
# 11                 Bangladesh     161200886  1210.15876939761
# 12                   Barbados        284217  16129.0492827663
# 13                    Belarus       9489616  5949.10630699748
# ...

# %%
pop = pop.fillna('None')

# %%
pop = pop[pop.mortality_rate != 'None']  #get rid of rows with no reported mortality rate
pop = pop.reset_index()

# %%
pop = pop.drop(columns=['index'])

# %%
pop
# Out:
#                        Country Name 2015 [YR2015]               gdp  \
# 0                       Afghanistan      33736494    569.5779229167
# 1                           Albania       2880703  3952.83078116586
# 2                           Algeria      39871528  4160.22006671831
# 3                            Angola      27859305   3683.5526074127
# 4                         Argentina      43417765  13698.2934384857
# 5                           Armenia       2916950  3617.93574555176
# 6                         Australia      23850784  56561.4123818054
# 7                           Austria       8642699  44206.7842820834
# 8                        Azerbaijan       9649341  5500.31038244408
# 9                           Bahrain       1371855  22688.8782442968
# 10                       Bangladesh     161200886  1210.15876939761
# 11                         Barbados        284217  16129.0492827663
# 12                          Belarus       9489616  5949.10630699748
# ...

# %%
pop = pop.rename(columns={'2015 [YR2015]':'population'})

# %%
# pop = pop.drop(columns=['index'])
pop
# Out:
#                        Country Name population               gdp  \
# 0                       Afghanistan   33736494    569.5779229167
# 1                           Albania    2880703  3952.83078116586
# 2                           Algeria   39871528  4160.22006671831
# 3                            Angola   27859305   3683.5526074127
# 4                         Argentina   43417765  13698.2934384857
# 5                           Armenia    2916950  3617.93574555176
# 6                         Australia   23850784  56561.4123818054
# 7                           Austria    8642699  44206.7842820834
# 8                        Azerbaijan    9649341  5500.31038244408
# 9                           Bahrain    1371855  22688.8782442968
# 10                       Bangladesh  161200886  1210.15876939761
# 11                         Barbados     284217  16129.0492827663
# 12                          Belarus    9489616  5949.10630699748
# ...

# %%
pop= pop.replace(to_replace= 'NaN', value= 'None')
pop.head()
# Out:
#   Country Name population               gdp maternity_leaves  fertility_rate  \
# 0  Afghanistan   33736494    569.5779229167                1             4.8
# 1      Albania    2880703  3952.83078116586                1             1.7
# 2      Algeria   39871528  4160.22006671831                1             2.8
# 3       Angola   27859305   3683.5526074127                1             5.8
# 4    Argentina   43417765  13698.2934384857                1             2.3
#
#    mortality_rate  healthcare
# 0           396.0         0.0
# 1            29.0         0.0
# 2           140.0         0.0
# 3           477.0         0.0
# 4            52.0         0.0

# %%
type(pop.iloc[0].fertility_rate)
# Out:
# numpy.float64

# %%
countries_pop = countries_pop[:-5]

# %%
countries_pop
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'European Union',
#  'Faroe Islands',
#  'Fiji',
# ...

# %%
def new_column(name, csv, column):
    df = pd.read_csv(csv)  #get csv, turn info into dataframe
    df = df[['Country Name', column]]  #new dataframe with interested columns

    df_countries = df['Country Name'].tolist()  #get a list of all country values from dataframe
    df_vals = []  #start empty list for values we are interested in

    for country in countries:  #countries that we want to focus on
        try:
            index = df_countries.index(country)  #if the country from the new df is in the country list we are interested in, we append that country's info to list
            df_vals.append(df.loc[index, column])

        except:
            print(country)  #otherwise, nothing        
    
    if len(df_vals) == 175:
        pop[name] = df_vals
    else:
        return len(df_vals)

# %%
countries = pop['Country Name'].tolist()
new_column('fertile_women_pop', 'fertilewomen - fertilewomen2.csv', 'Women Who are fertile')

# %%
pop
# Out:
#                        Country Name population               gdp  \
# 0                       Afghanistan   33736494    569.5779229167
# 1                           Albania    2880703  3952.83078116586
# 2                           Algeria   39871528  4160.22006671831
# 3                            Angola   27859305   3683.5526074127
# 4                         Argentina   43417765  13698.2934384857
# 5                           Armenia    2916950  3617.93574555176
# 6                         Australia   23850784  56561.4123818054
# 7                           Austria    8642699  44206.7842820834
# 8                        Azerbaijan    9649341  5500.31038244408
# 9                           Bahrain    1371855  22688.8782442968
# 10                       Bangladesh  161200886  1210.15876939761
# 11                         Barbados     284217  16129.0492827663
# 12                          Belarus    9489616  5949.10630699748
# ...

# %%
#df.mycol.fillna(value=pd.np.nan, inplace=True)
import numpy as np
pop.replace(to_replace='None', value=np.nan, inplace=True)

# %%
# countries = pop['Country Name'].tolist()
pop
# Out:
#                        Country Name population               gdp  \
# 0                       Afghanistan   33736494    569.5779229167
# 1                           Albania    2880703  3952.83078116586
# 2                           Algeria   39871528  4160.22006671831
# 3                            Angola   27859305   3683.5526074127
# 4                         Argentina   43417765  13698.2934384857
# 5                           Armenia    2916950  3617.93574555176
# 6                         Australia   23850784  56561.4123818054
# 7                           Austria    8642699  44206.7842820834
# 8                        Azerbaijan    9649341  5500.31038244408
# 9                           Bahrain    1371855  22688.8782442968
# 10                       Bangladesh  161200886  1210.15876939761
# 11                         Barbados     284217  16129.0492827663
# 12                          Belarus    9489616  5949.10630699748
# ...

# %%
# new_column('fertility_percentage', 'fertilewomen - fertilewomen.csv')

# %%
new_column('mortality_rate_adj', 'fertilewomen - fertilewomen2.csv', 'Mortality_Adjusted')

# %%
new_column('hc_expend', 'healthcare_expenditure.csv', '2015')

# %%
new_column('w_lit_pop', 'fertilewomen - fertilewomen3.csv', 'Women Lit Pop')

# %%
pop['w_lit_pop'].replace(0, np.nan, inplace=True)

# %%
pop.head()
# Out:
#   Country Name population               gdp  maternity_leaves  fertility_rate  \
# 0  Afghanistan   33736494    569.5779229167               1.0             4.8
# 1      Albania    2880703  3952.83078116586               1.0             1.7
# 2      Algeria   39871528  4160.22006671831               1.0             2.8
# 3       Angola   27859305   3683.5526074127               1.0             5.8
# 4    Argentina   43417765  13698.2934384857               1.0             2.3
#
#    mortality_rate  healthcare  fertile_women_pop  mortality_rate_adj  \
# 0           396.0         0.0       7.586627e+06            0.000000
# 1            29.0         0.0       7.070754e+05         2800.018771
# 2           140.0         0.0       1.073062e+07        51185.054810
# 3           477.0         0.0       6.348298e+06         9903.345577
# 4            52.0         0.0       1.080426e+07         2701.064872
#
#     hc_expend  w_lit_pop
# 0   60.088813        NaN
# 1  265.903236        NaN
# ...

# %%
pop= pop[['Country Name', 'population', 'w_lit_pop', 'fertile_women_pop', 'fertility_rate', 'maternity_leaves', 'gdp', 'healthcare', 'hc_expend', 'mortality_rate', 'mortality_rate_adj']]
pop.head()
# Out:
#   Country Name population  w_lit_pop  fertile_women_pop  fertility_rate  \
# 0  Afghanistan   33736494        NaN       7.586627e+06             4.8
# 1      Albania    2880703        NaN       7.070754e+05             1.7
# 2      Algeria   39871528        NaN       1.073062e+07             2.8
# 3       Angola   27859305        NaN       6.348298e+06             5.8
# 4    Argentina   43417765        NaN       1.080426e+07             2.3
#
#    maternity_leaves               gdp  healthcare   hc_expend  mortality_rate  \
# 0               1.0    569.5779229167         0.0   60.088813           396.0
# 1               1.0  3952.83078116586         0.0  265.903236            29.0
# 2               1.0  4160.22006671831         0.0  291.635898           140.0
# 3               1.0   3683.5526074127         0.0  108.559535           477.0
# 4               1.0  13698.2934384857         0.0  997.931375            52.0
#
#    mortality_rate_adj
# 0            0.000000
# ...

# %%
#THIS IS TEST/TRAIN SPLIT DATA
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
#loading dataset for training models
y= pop.mortality_rate
X_train, X_test, y_train, y_test = train_test_split(pop, y, test_size=0.2)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (140, 11) (140,)
# (35, 11) (35,)

# %%
# type(pop.iloc[0].fertility_rate2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
mr = pop.plot(kind='scatter', x='fertile_women_pop', y='mortality_rate', alpha=1) #scatter plot fertile women pop vs. mortality rate

# %%
feature_cols = ['fertile_women_pop']
X = pop[feature_cols]
Y = pop.mortality_rate

# %%
#use stats model ols model
import statsmodels.api as sm

X_sm = pop[feature_cols]
y_sm = pop.mortality_rate
X_sm = sm.add_constant(X_sm) #this constant is the intercept
sm_model = sm.OLS(y_sm, X_sm).fit()
print(sm_model.summary())
print(sm_model.rsquared_adj)

#little to no relationship between fertility rate and maternal mortality rate
#p value >.05 and r^2 < 0.75
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         mortality_rate   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.4649
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):              0.496
# Time:                        11:21:59   Log-Likelihood:                -1201.7
# No. Observations:                 175   AIC:                             2407.
# Df Residuals:                     173   BIC:                             2414.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               170.8197     18.365      9.301      0.000     134.570     207.069
# ...

# %%
mrfr = pop.plot(kind='scatter', x='fertility_rate', y='mortality_rate', alpha=1) #scatter plot fertile rate vs. mortality rate

# %%
#multiple variabe
feature= ['fertility_rate']
X= pop[feature]
y= pop.mortality_rate


X_sm = pop[feature]
y_sm = pop.mortality_rate
X_sm = sm.add_constant(X_sm) #this constant is the intercept
sm_model = sm.OLS(y_sm, X_sm).fit()
print(sm_model.summary())
print(sm_model.rsquared_adj)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         mortality_rate   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     353.6
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):           1.13e-43
# Time:                        11:21:59   Log-Likelihood:                -1104.6
# No. Observations:                 175   AIC:                             2213.
# Df Residuals:                     173   BIC:                             2219.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           -221.8006     23.046     -9.624      0.000    -267.289    -176.312
# ...

# %%
'''There is significant relationship between fertility rate and maternal mortility rate. the r^2 value is .671 with a high T-test and probablity < 0.05. We can reject the null'''
# Out:
# 'There is significant relationship between fertility rate and maternal mortility rate. the r^2 value is .671 with a high T-test and probablity < 0.05. We can reject the null'

# %%
from statsmodels.formula.api import ols
f= 'mortality_rate~fertility_rate'

# %%
model= ols(formula=f, data=pop).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         mortality_rate   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     353.6
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):           1.13e-43
# Time:                        11:21:59   Log-Likelihood:                -1104.6
# No. Observations:                 175   AIC:                             2213.
# Df Residuals:                     173   BIC:                             2219.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
fig= plt.figure(figsize=(15,8))
fig= sm.graphics.plot_regress_exog(model, 'fertility_rate', fig=fig)
plt.show()

# %%
import scipy.stats as stats
residuals= model.resid
fig= sm.graphics.qqplot(residuals, dist= stats.norm, line= '45', fit=True)
fig.show()
# Out:
# /Users/Iffy/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
pop["gdp"] = pd.to_numeric(pop["gdp"])

# %%
pop= pop[pop['gdp'].notnull()]
pop
# Out:
#                        Country Name population     w_lit_pop  \
# 0                       Afghanistan   33736494           NaN
# 1                           Albania    2880703           NaN
# 2                           Algeria   39871528           NaN
# 3                            Angola   27859305           NaN
# 4                         Argentina   43417765           NaN
# 5                           Armenia    2916950           NaN
# 6                         Australia   23850784           NaN
# 7                           Austria    8642699  4.399174e+06
# 8                        Azerbaijan    9649341           NaN
# 9                           Bahrain    1371855           NaN
# 10                       Bangladesh  161200886           NaN
# 11                         Barbados     284217           NaN
# 12                          Belarus    9489616           NaN
# 13                          Belgium   11274196           NaN
# ...

# %%
pop['population']= pd.to_numeric(pop['population'])
pop= pop[pop['population'].notnull()]
pop
# Out:
# /Users/Iffy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        Country Name  population     w_lit_pop  \
# 0                       Afghanistan    33736494           NaN
# 1                           Albania     2880703           NaN
# 2                           Algeria    39871528           NaN
# 3                            Angola    27859305           NaN
# 4                         Argentina    43417765           NaN
# 5                           Armenia     2916950           NaN
# 6                         Australia    23850784           NaN
# 7                           Austria     8642699  4.399174e+06
# ...

# %%
pop['hc_expend']= pd.to_numeric(pop['hc_expend'])
pop= pop[pop['hc_expend'].notnull()]
pop
# Out:
#                        Country Name  population     w_lit_pop  \
# 0                       Afghanistan    33736494           NaN
# 1                           Albania     2880703           NaN
# 2                           Algeria    39871528           NaN
# 3                            Angola    27859305           NaN
# 4                         Argentina    43417765           NaN
# 5                           Armenia     2916950           NaN
# 6                         Australia    23850784           NaN
# 7                           Austria     8642699  4.399174e+06
# 8                        Azerbaijan     9649341           NaN
# 9                           Bahrain     1371855           NaN
# 10                       Bangladesh   161200886           NaN
# 11                         Barbados      284217           NaN
# 12                          Belarus     9489616           NaN
# 13                          Belgium    11274196           NaN
# ...

# %%
pop['w_lit_pop']= pd.to_numeric(pop['w_lit_pop'])
pop= pop[pop['w_lit_pop'].notnull()]
pop
# Out:
# /Users/Iffy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        Country Name  population     w_lit_pop  \
# 7                           Austria     8642699  4.399174e+06
# 16                           Bhutan      787386  3.268212e+05
# 24                          Burundi    10199270  4.253066e+06
# 43                          Denmark     5683483  2.637859e+06
# 44                         Djibouti      927414  4.307085e+05
# 45               Dominican Republic    10528394  4.554241e+06
# 58                          Georgia     3717100  1.707811e+06
# 73               Iran, Islamic Rep.    79360487  3.723890e+07
# ...

# %%
features= ['gdp']

# %%
X = pop[features]
Y = pop.mortality_rate

X_sm = pop[features]
y_sm = pop.mortality_rate
X_sm = sm.add_constant(X_sm) #this constant is the intercept
sm_model = sm.OLS(y_sm, X_sm).fit()
print(sm_model.summary())
print(sm_model.rsquared_adj)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         mortality_rate   R-squared:                       0.178
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     35.90
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):           1.25e-08
# Time:                        11:22:00   Log-Likelihood:                -1136.2
# No. Observations:                 168   AIC:                             2276.
# Df Residuals:                     166   BIC:                             2283.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        235.2559     19.974     11.778      0.000     195.820     274.692
# ...

# %%
mrgdp = pop.plot(kind='scatter', x='gdp', y='mortality_rate', alpha=1) #scatter plot fertile rate vs. mortality rate

# %%
featureh= ['healthcare']
X = pop[featureh]
Y = pop.mortality_rate

X_sm = pop[featureh]
y_sm = pop.mortality_rate
X_sm = sm.add_constant(X_sm) #this constant is the intercept
sm_model = sm.OLS(y_sm, X_sm).fit()
print(sm_model.summary())
print(sm_model.rsquared_adj)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         mortality_rate   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     18.24
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):           3.28e-05
# Time:                        11:22:00   Log-Likelihood:                -1143.9
# No. Observations:                 168   AIC:                             2292.
# Df Residuals:                     166   BIC:                             2298.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        198.8705     18.704     10.632      0.000     161.941     235.800
# ...

# %%
sns.catplot(y="mortality_rate", x="healthcare", kind="box", data=pop);

# %%
mrgdp= pop.plot(kind='bar', x='gdp', y= 'mortality_rate', legend=False, figsize=(30,5))

# %%
sns.catplot(y="mortality_rate", x="gdp", kind="box", data=pop);

# %%
sns.catplot(y="gdp", x="healthcare", kind="box", data=pop);

# %%
'''X = df[[“RM”, “LSTAT”]]
y = target[“MEDV”]
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()'''
X= pop[['fertility_rate', 'gdp', 'healthcare', 'population', 'hc_expend', 'w_lit_pop']]
y= pop['mortality_rate']
model= sm.OLS(y, X).fit()
predictions= model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         mortality_rate   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.778
# Method:                 Least Squares   F-statistic:                     23.71
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):           1.18e-10
# Time:                        11:27:01   Log-Likelihood:                -231.79
# No. Observations:                  39   AIC:                             475.6
# Df Residuals:                      33   BIC:                             485.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
f2= 'gdp~population'
model2= ols(formula=f2, data=pop).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    gdp   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                   0.04655
# Date:                Thu, 06 Dec 2018   Prob (F-statistic):              0.829
# Time:                        11:22:05   Log-Likelihood:                -1884.4
# No. Observations:                 168   AIC:                             3773.
# Df Residuals:                     166   BIC:                             3779.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.295e+04   1455.914      8.892      0.000    1.01e+04    1.58e+04
# ...

# %%
fig= plt.figure(figsize=(15,8))
fig= sm.graphics.plot_regress_exog(model2, 'population', fig=fig)
plt.show()

# %%
# for each in pop.population.astype('float')

# pop["gdp"] = pd.to_numeric(pop["gdp"])

# %%
# pop.iloc[0].population * pop.iloc[0].fertility_rate2

# %%
# import numpy as np
# fr = pop.fertility_rate2.tolist()
# popu = pop.population.tolist()
# np.asarray(fr) * np.asarray(popu)

# %%
# pop = pop.set_value(48, 'population', 4846976)   

# popul = pop.population.tolist()

# %%
# np.asarray(fr)[0] * np.asarray(popul)[0]

# %%
# percentage_pop = []
# for i in range(len(countries)):
#     percentage_pop.append(int(np.asarray(popul)[i]) * np.asarray(fr)[i])
