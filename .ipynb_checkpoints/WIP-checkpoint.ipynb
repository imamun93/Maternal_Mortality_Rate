# %%
from bs4 import BeautifulSoup
import requests

# %%
alc_request = requests.get('https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1310061801&pickMembers%5B0%5D=2.5&pickMembers%5B1%5D=3.3&pickMembers%5B2%5D=5.1')
alc_html = alc_request.text
alc_soup = BeautifulSoup(alc_html)

# %%
import pandas as pd

# %%
df = pd.read_csv('population.csv')
df.iloc[:, 2:]
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                              Albania          ALB
# 2                                              Algeria          DZA
# 3                                       American Samoa          ASM
# 4                                              Andorra          AND
# 5                                               Angola          AGO
# 6                                  Antigua and Barbuda          ATG
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                                Aruba          ABW
# 10                                           Australia          AUS
# 11                                             Austria          AUT
# 12                                          Azerbaijan          AZE
# ...

# %%
# df[['Country Name','2015 [YR2015]']]

df = df.rename(columns={'Country Name': 'Country', '2015 [YR2015]': 'Population'})

# %%
pop = df[['Country', 'Population']]

# %%
fr_df = pd.read_csv('fertility_rate.csv')
fr_df = fr_df.rename(columns = {'2015 [YR2015]': 'Fertility Rate'})

fr = fr_df[['Country Name', 'Fertility Rate']]

pop
# Out:
#                                                Country  Population
# 0                                          Afghanistan    33736494
# 1                                              Albania     2880703
# 2                                              Algeria    39871528
# 3                                       American Samoa       55537
# 4                                              Andorra       78014
# 5                                               Angola    27859305
# 6                                  Antigua and Barbuda       99923
# 7                                            Argentina    43417765
# 8                                              Armenia     2916950
# 9                                                Aruba      104341
# 10                                           Australia    23850784
# 11                                             Austria     8642699
# 12                                          Azerbaijan     9649341
# ...

# %%
fr
# Out:
#                  Country Name  Fertility Rate
# 0                 Afghanistan             4.8
# 1                     Albania             1.7
# 2                     Algeria             2.8
# 3              American Samoa             NaN
# 4                     Andorra             NaN
# 5                      Angola             5.8
# 6         Antigua and Barbuda             2.1
# 7                  Arab World             3.4
# 8                   Argentina             2.3
# 9                     Armenia             1.6
# 10                      Aruba             1.8
# 11                  Australia             1.8
# 12                    Austria             1.5
# 13                 Azerbaijan             1.9
# 14               Bahamas, The             1.8
# 15                    Bahrain             2.1
# 16                 Bangladesh             2.1
# 17                   Barbados             1.8
# 18                    Belarus             1.7
# ...

# %%
pd.read_csv('pop.csv')
# Out:
#                                               Series Name  \
# 0       Women who own a house both alone and jointly (...
# 1       Women who own a house both alone and jointly (...
# 2       Women who own a house both alone and jointly (...
# 3       Women who own a house both alone and jointly (...
# 4       Women who own a house both alone and jointly (...
# 5       Women who own a house both alone and jointly (...
# 6       Women who own a house both alone and jointly (...
# 7       Women who own a house both alone and jointly (...
# 8       Women who own a house both alone and jointly (...
# 9       Women who own a house both alone and jointly (...
# 10      Women who own a house both alone and jointly (...
# 11      Women who own a house both alone and jointly (...
# 12      Women who own a house both alone and jointly (...
# 13      Women who own a house both alone and jointly (...
# 14      Women who own a house both alone and jointly (...
# ...

# %%
import pandas as pd
pd.read_csv('http://databank.worldbank.org/data/embed/mean-pop-by-countries/id/ae137e04').jsonify()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-036db0aed769> in <module>()
#       1 import pandas as pd
# ----> 2 pd.read_csv('http://databank.worldbank.org/data/embed/mean-pop-by-countries/id/ae137e04').jsonify()
#
# ...
