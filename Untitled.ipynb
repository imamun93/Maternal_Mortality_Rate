# %%
import pandas as pd

# %%
meanpop= pd.read_csv('popmean.csv')
meanpop.tail(100)
# Out:
#                                Series Name  Series Code  \
# 107                      Population, total  SP.POP.TOTL
# 108                      Population, total  SP.POP.TOTL
# 109                      Population, total  SP.POP.TOTL
# 110                      Population, total  SP.POP.TOTL
# 111                      Population, total  SP.POP.TOTL
# 112                      Population, total  SP.POP.TOTL
# 113                      Population, total  SP.POP.TOTL
# 114                      Population, total  SP.POP.TOTL
# 115                      Population, total  SP.POP.TOTL
# 116                      Population, total  SP.POP.TOTL
# 117                      Population, total  SP.POP.TOTL
# 118                      Population, total  SP.POP.TOTL
# 119                      Population, total  SP.POP.TOTL
# 120                      Population, total  SP.POP.TOTL
# 121                      Population, total  SP.POP.TOTL
# 122                      Population, total  SP.POP.TOTL
# ...

# %%
len(meanpop)
# Out:
# 207
